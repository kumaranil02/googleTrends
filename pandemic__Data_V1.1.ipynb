# %%
###########################################################################################
# Google searches from data range '2020-01-01 to 2020-04-26' by the following key words

# Intrests analyzed by date

#'domestic flight','travel','vacation','resorts','hotels','travel visa','airline ticket',
#'best hotels','airbnb','park'

#For USA region and the category is Travel(67)

###########################################################################################


import pandas as pd                        
from pytrends.request import TrendReq
pytrend = TrendReq()

pytrend = TrendReq(hl='en-US',geo = 'US', tz=360)

start_dt = '2020-01-01'

end_dt = '2020-04-26'

keywords = ['domestic flight','travel','vacation','resorts','hotels',
            'travel visa','airline ticket','best hotels','airbnb','park']
key = []
for i in keywords:
    key.append([i])
key

for i in range(0,len(key)):
    pytrend.build_payload(
        kw_list=key[i],
        cat=67,
        timeframe= start_dt + ' ' + end_dt ,
        geo='US',
        gprop='')
    data = pytrend.interest_over_time()
    data = data.drop(labels=['isPartial'],axis='columns')
    if i == 0:
        data1 = data
    else:
        data1 = pd.merge(data1, data, on='date')

data1 = data1[sorted([col for col in data1.columns])]
data1
#data1.to_csv(r'C:\Users\Anil\OneDrive\Desktop\AnujAdhoc\google-topics-by-date1.csv')
# Out:
#             airbnb  airline ticket  best hotels  domestic flight  hotels  \
# date
# 2020-01-01      64              30           61                2      66
# 2020-01-02      87              39           78               11      77
# 2020-01-03      86              38           86                6      77
# 2020-01-04      84              55           70                6      74
# 2020-01-05      80              69           86                9      76
# ...            ...             ...          ...              ...     ...
# 2020-04-19      22              30           19                2      34
# 2020-04-20      25               5           16                2      27
# 2020-04-21      22              10           20                2      27
# 2020-04-22      23              26           13                2      27
# 2020-04-23      25              31           21                4      29
#
#             park  resorts  travel  travel visa  vacation
# date
# ...

# %%
###########################################################################################
# Google searches from data range '2020-01-01 to 2020-04-26' by the following key words

#Intrests analyzed by region

#'domestic flight','travel','vacation','resorts','hotels','travel visa','airline ticket',
#'best hotels','airbnb','park'

#For USA region and the category is Travel(67)

###########################################################################################

import pandas as pd                        
from pytrends.request import TrendReq
pytrend = TrendReq()

start_dt = '2020-01-01'

end_dt = '2020-04-26'

pytrend = TrendReq(hl='en-US',geo = 'US', tz=360)

keywords = ['domestic flight','travel','vacation','resorts','hotels',
            'travel visa','airline ticket','best hotels','airbnb','park']
key = []
for i in keywords:
    key.append([i])
    
for i in range(0,len(key)):
    pytrend.build_payload(
        kw_list=key[i],
        cat=67,
        timeframe=start_dt + ' ' + end_dt,
        geo='US',
        gprop='')
    data = pytrend.interest_by_region()
    if i == 0:
        data1 = data
    else:
        data1 = pd.merge(data1, data, on='geoName')

data1  = data1[sorted([col for col in data1.columns])]
data1['date'] = end_dt
#data1.to_csv(r'C:\Users\Anil\OneDrive\Desktop\AnujAdhoc\google-topics-by-region1.csv')

# %%
data1
# Out:
#                       airbnb  airline ticket  best hotels  domestic flight  \
# geoName
# Alabama                   28              20           41               20
# Alaska                    57             100           36               46
# Arizona                   40              46           50               26
# Arkansas                  27              34           44               10
# California                53              45           62               39
# Colorado                  50              36           53               48
# Connecticut               39              27           61               27
# Delaware                  43              58           53               27
# District of Columbia      71              63          100               33
# Florida                   45              45           62               36
# Georgia                   38              39           49               28
# ...

# %%
import pymysql
connection = pymysql.connect(host='127.0.0.1',
                             user='anil',
                             password='anil',
                             db='testpd')

# %%
data2 = data1.reset_index()
date = data2['date']
date
# Out:
# 0     2020-01-01
# 1     2020-01-02
# 2     2020-01-03
# 3     2020-01-04
# 4     2020-01-05
#          ...
# 109   2020-04-19
# 110   2020-04-20
# 111   2020-04-21
# 112   2020-04-22
# 113   2020-04-23
# Name: date, Length: 114, dtype: datetime64[ns]

# %%
airbnb = data2['airbnb']
airline_ticket = data2['airline ticket']
airline_ticket
# Out:
# 0      30
# 1      39
# 2      38
# 3      55
# 4      69
#        ..
# 109    30
# 110     5
# 111    10
# 112    26
# 113    31
# Name: airline ticket, Length: 114, dtype: int32

# %%
#########################################################################################
#To connect to data base we need to initlialise local host port for listening
#
#
#cloud_sql_proxy -instances= <instance name> -credential_file=<json file> &
#json file = C:\Users\Anil\OneDrive\Desktop\AnujAdhoc\abc.json
#cloudapi-260317:us-central1:pandamic-database=tcp:3306
#
#
#
#reference : https://github.com/GoogleCloudPlatform/python-docs-samples/blob/master/cloud-sql/mysql/sqlalchemy/main.py
#


#########################################################################################

# %%
import sqlalchemy

db = sqlalchemy.create_engine('mysql+pymysql://anil:anil@127.0.0.1:3306/testpd')

# %%
a = "'2020-08-19'"
b = "'84'"
s1 = 'INSERT INTO gdata (date, airbnb) VALUES ('
s2 = ')'
k = s1 + a +',' + b + s2
print(k)

s = "INSERT INTO gdata (date, airbnb)" " VALUES ('2020-04-28', '98')"
print(s)
stmt = sqlalchemy.text(k)
    # Using a with statement ensures that the connection is always released
    # back into the pool at the end of statement (even if an error occurs)
# stmt = sqlalchemy.text(
#         "INSERT INTO gdata (date, airbnb)" " VALUES ('2020-04-26', '58')"
#     )
with db.connect() as conn:
    conn.execute(stmt)
print(stmt)
# Out:
# INSERT INTO gdata (date, airbnb) VALUES ('2020-08-19','84')
# INSERT INTO gdata (date, airbnb) VALUES ('2020-04-28', '98')
# INSERT INTO gdata (date, airbnb) VALUES ('2020-08-19','84')

# %%
with db.connect() as conn:
#         conn.execute(
#             "CREATE TABLE IF NOT EXISTS gtd3 "
#             "(date  char,airbnb int,airline_ticket int,best_hotels int,domestic_flight int,"
#             "hotels int,park int,resorts int,travel int,travel_visa int,vacation int);"
#         )
        conn.execute(
            "CREATE TABLE IF NOT EXISTS gdata"
            "(date  char(20),airbnb int);"
        )
#         a = conn.execute("select date from gtd")
#         a = a.fetchall()

# %%
import pandas as pd
a = pd.DataFrame(a)
a
# Out:
#               0
# 0    0000-00-00
# 1    0000-00-00
# 2    0000-00-00
# 3    0000-00-00
# 4    0000-00-00
# ..          ...
# 110  0000-00-00
# 111  0000-00-00
# 112  0000-00-00
# 113  0000-00-00
# 114  0000-00-00
#
# [115 rows x 1 columns]
